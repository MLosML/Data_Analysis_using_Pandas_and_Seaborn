# %% [markdown]
# # Data Cleaning with Pandas

# %%
import pandas as pd

# %%
# orders.csv
url = "https://drive.google.com/file/d/1Vu0q91qZw6lqhIqbjoXYvYAQTmVHh6uZ/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders = pd.read_csv(path)

# orderlines.csv
url = "https://drive.google.com/file/d/1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orderlines = pd.read_csv(path)

# %%
orders_df = orders.copy()

# %%
orderlines_df = orderlines.copy()

# %% [markdown]
# ## 1.&nbsp; Duplicates

# %%
# orders
orders_df.duplicated().sum()
# Out:
# 0

# %%
# orderlines
orderlines_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 2.&nbsp; `.info()`

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# * `total_paid` has 5 missing values
# * `created_date` should become datetime datatype

# %%
orderlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %% [markdown]
# * `date` should be a datetime datatype
# * `unit_price` should be a float datatype

# %% [markdown]
# ## 3.&nbsp; Missing values

# %% [markdown]
# ### 3.1.&nbsp; Orders
# * `total_paid` has 5 missing values

# %%
print(f"5 missing values represents {((orders_df.total_paid.isna().sum() / orders_df.shape[0])*100).round(5)}% of the rows in our DataFrame")
# Out:
# 5 missing values represents 0.0022% of the rows in our DataFrame

# %%
orders_df.total_paid.isna().value_counts(normalize=True)
# Out:
# total_paid
# False    0.999978
# True     0.000022
# Name: proportion, dtype: float64

# %% [markdown]
# As there is such a tiny amount of missing values, I will simply delete these rows, as I have enough data without them.

# %%
orders_df = orders_df.loc[~orders.total_paid.isna(), :]

# %% [markdown]
# ### 3.2.&nbsp; Orderlines
# There are no missing values in `orderlines`

# %% [markdown]
# ## 4.&nbsp; Datatypes

# %% [markdown]
# ### 4.1.&nbsp; Orders
# * `created_date` should become datetime datatype

# %%
orders_df["created_date"] = pd.to_datetime(orders_df["created_date"])
# Out:
# <ipython-input-70-87c26cc5d8b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orders_df["created_date"] = pd.to_datetime(orders_df["created_date"])

# %% [markdown]
# ### 4.1.&nbsp; Orderlines
# * `date` should be a datetime datatype
# * `unit_price` should be a float datatype

# %% [markdown]
# #### 4.1.1.&nbsp; `date`

# %%
orderlines_df["date"] = pd.to_datetime(orderlines_df["date"])

# %% [markdown]
# #### 4.1.2.&nbsp;`unit_price`

# %%
orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.137.99"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-d6bd38092a9f> in <cell line: 1>()
# ----> 1 orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast, dtype_backend)
#     220         coerce_numeric = errors not in ("ignore", "raise")
#     221         try:
# --> 222             values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa: E501
#     223                 values,
#     224                 set(),
#
# lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "1.137.99" at position 6

# %% [markdown]
#  When I try to convert `unit_price` to a numerical datatype, I receive a `ValueError` telling me that pandas doesn't understand the number `1.137.99`. This is probably because numbers cannot have 2 decimal points. Let's see if there are any other numbers like this.*kursiver Text*

# %%
orderlines_df.unit_price.str.contains("\d+\.\d+\.\d+").value_counts()
# Out:
# unit_price
# False    257814
# True      36169
# Name: count, dtype: int64

# %% [markdown]
# Looks like over 36000 rows in `orderlines` are affected by this problem. Let's work out how much that is as a percentage of our total data.

# %%
two_dot_percentage = ((orderlines_df.unit_price.str.contains("\d+\.\d+\.\d+").value_counts()[1] / orderlines_df.shape[0])*100).round(2)
print(f"The 2 dot problem represents {two_dot_percentage}% of the rows in our DataFrame")
# Out:
# The 2 dot problem represents 12.3% of the rows in our DataFrame
# <ipython-input-75-d7cb20f99e43>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   two_dot_percentage = ((orderlines_df.unit_price.str.contains("\d+\.\d+\.\d+").value_counts()[1] / orderlines_df.shape[0])*100).round(2)

# %% [markdown]
# This is a bit of a tricky decision as 12.3% is a significant amount of our data... and I might even end up losing a larger portion of the data than this too. For the moment I will delete the rows as I only have 2 weeks for this project and I'd like some quick, accurate results to show.
#
# Each row of `orderlines` represents a product in an order. For example, if order number 175 contained 3 seperate products, then order 175 would have 3 rows in `orderlines`, one row for each of the products. If 2 of those products have 'normal' prices (14.99, 15.85) and 1 has a price with 2 decimal points (1.137.99), I need to remove the whole order and not just the affected row. If I only remove the row with 2 decimal places then any later analysis about products and prices could be misleading.
#
# I therefore need to find the order numbers associated with the rows that have 2 decimal points, and then remove all the associated rows.

# %%
two_dot_order_ids_list = orderlines_df.loc[orderlines_df.unit_price.str.contains("\d+\.\d+\.\d+"), "id_order"]

orderlines_df = orderlines_df.loc[~orderlines_df.id_order.isin(two_dot_order_ids_list)]

# %%
orderlines_df.shape[0]
# Out:
# 216250

# %% [markdown]
# I still have 216250 rows in orderlines to work with. This should be more than enough for our evaluation.
#
# Now that all of the 2 decimal point prices have been removed, let's try again to convert the column `unit_price` to the correct datatype.

# %%
orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])
# Out:
# <ipython-input-78-d6bd38092a9f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   orderlines_df["unit_price"] = pd.to_numeric(orderlines_df["unit_price"])

# %% [markdown]
# It worked perfectly

# %% [markdown]
# #Clean the `products` DataFrame

# %%
# products.csv
url = "https://drive.google.com/file/d/1afxwDXfl-7cQ_qLwyDitfcCx3u7WMvkU/view?usp=sharing"
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
products = pd.read_csv(path)

# %%
products_df = products.copy()

# %%
products_df.head()
# Out:
#        sku                                           name  \
# 0  RAI0007              Silver Rain Design mStand Support
# 1  APP0023              Apple Mac Keyboard Keypad Spanish
# 2  APP0025               Mighty Mouse Apple Mouse for Mac
# 3  APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4  KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
#
#                                                 desc  price promo_price  \
# 0       Aluminum support compatible with all MacBook  59.99     499.899
# 1          USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                             mouse Apple USB cable.     59     569.898
# 3              IPhone dock and USB Cable Apple iPod.     25     229.997
# 4  2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
#
#    in_stock      type
# 0         1      8696
# 1         0  13855401
# 2         0      1387
# 3         0      1230
# 4         1      1364

# %% [markdown]
# ## Duplicates

# %%
products_df.duplicated().sum()
# Out:
# 8746

# %% [markdown]
# Let's get rid of the duplicates

# %%
products_df = products_df.drop_duplicates()

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0             1      8696
# 1             0  13855401
# 2             0      1387
# 3             0      1230
# 4             1      1364
# ...         ...       ...
# 19321         1     12282
# 19322         1      1392
# 19323         1      1392
# 19324         0      1392
# 19325         1      1392
#
# [10580 rows x 7 columns]

# %% [markdown]
# ## `.info()`

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10580 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10580 non-null  object
#  1   name         10580 non-null  object
#  2   desc         10573 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10580 non-null  object
#  5   in_stock     10580 non-null  int64
#  6   type         10530 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 661.2+ KB

# %% [markdown]
# ### Missing values
# You can see from `.info()` above that I have missing values in `desc` and `price`

# %% [markdown]
# #### `desc`

# %%
products_df["desc"].isna().sum()
# Out:
# 7

# %% [markdown]
# 7 is a very small number to have missing, let's have a closer look

# %%
products_df.loc[products_df['desc'].isna(), :]
# Out:
#              sku                                               name desc  \
# 16126  WDT0211-A  Open - Purple 2TB WD 35 "PC Security Mac hard ...  NaN
# 16128  APP1622-A  Open - Apple Smart Keyboard Pro Keyboard Folio...  NaN
# 17843    PAC2334             Synology DS718 + NAS Server | 10GB RAM  NaN
# 18152  KAN0034-A  Open - Kanex USB-C Gigabit Ethernet Adapter Ma...  NaN
# 18490    HTE0025  Hyper Pearl 1600mAh battery Mini USB Mirror an...  NaN
# 18612    OTT0200    OtterBox External Battery Power Pack 20000 mAHr  NaN
# 18690  HOW0001-A  Open - Honeywell thermostat Lyric zonificador ...  NaN
#
#            price promo_price  in_stock      type
# 16126        107     814.659         0      1298
# 16128  1.568.206   1.568.206         0      1298
# 17843     566.35   5.659.896         0  12175397
# 18152      29.99     237.925         0      1298
# 18490      24.99       22.99         1      1515
# 18612      79.99       56.99         1      1515
# 18690     199.99   1.441.174         0  11905404

# %% [markdown]
# The products names here are quite descriptive, so I'm tempted to just copy them to the description column, so that there is a description if I later want utilise this column. I wouldn't recommend this if this DataFrame was the source of truth for the website. But this is not the case here, and I'm not faking any information (guessing a price or so), so I'm happy with this option

# %% [markdown]
# #### `price`

# %%
products_df.price.isna().sum()
# Out:
# 46

# %%
print(f"The missing values in price are {(products_df.price.isna().value_counts(normalize=True)[1] * 100).round(2)}% of all rows in the DataFrame")
# Out:
# The missing values in price are 0.43% of all rows in the DataFrame
# <ipython-input-89-149a8976a30c>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"The missing values in price are {(products_df.price.isna().value_counts(normalize=True)[1] * 100).round(2)}% of all rows in the DataFrame")

# %% [markdown]
# Let's simply delete these rows to ensure that we can trust the numbers in our final DataFrame. Afterall, the price is very important when investigating discounts.

# %% [markdown]
# Option 1: `.loc`

# %%
products_df = products_df.loc[~products['price'].isna()]

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10534 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10534 non-null  object
#  1   name         10534 non-null  object
#  2   desc         10527 non-null  object
#  3   price        10534 non-null  object
#  4   promo_price  10534 non-null  object
#  5   in_stock     10534 non-null  int64
#  6   type         10484 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 658.4+ KB

# %% [markdown]
# #### `price`

# %% [markdown]
# First, let's see how many values are affected by the 2-decimal-dot problems or 3 decimal places.

# %%
price_problems_number = products_df.loc[(products_df.price.astype(str).str.contains("\d+\.\d+\.\d+"))|(products_df.price.astype(str).str.contains("\d+\.\d{3,}")), :].shape[0]
price_problems_number
# Out:
# 542

# %%
print(f"The column price has in total {price_problems_number} wrong values. This is {round(((price_problems_number / products_df.shape[0]) * 100), 2)}% of the rows of the DataFrame")
# Out:
# The column price has in total 542 wrong values. This is 5.15% of the rows of the DataFrame

# %% [markdown]
# 5.15% is a reasonable amount of our data. However, the price column will be important to understanding discounts, so I'd like it to be very trustworthy as I am  basing business decisions on it. Therefore, I will delete these rows

# %%
products_df = products_df.loc[(~products_df.price.astype(str).str.contains("\d+\.\d+\.\d+"))&(~products_df.price.astype(str).str.contains("\d+\.\d{3,}")), :]

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# 1              USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                                 mouse Apple USB cable.     59     569.898
# 3                  IPhone dock and USB Cable Apple iPod.     25     229.997
# 4      2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# ...                                                  ...    ...         ...
# 19321  compact and portable stand vertically or horiz...  29.99     269.903
# 19322  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19323  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19324  Backpack with capacity of 14 liter compartment...  69.95     649.903
# 19325  Backpack with capacity of 14 liter compartment...  69.95     649.903
#
#        in_stock      type
# 0             1      8696
# 1             0  13855401
# 2             0      1387
# 3             0      1230
# 4             1      1364
# ...         ...       ...
# 19321         1     12282
# 19322         1      1392
# 19323         1      1392
# 19324         0      1392
# 19325         1      1392
#
# [9992 rows x 7 columns]

# %% [markdown]
# To complete our task, let's convert the column to a numeric datatype

# %%
products_df["price"] = pd.to_numeric(products_df["price"])

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9992 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          9992 non-null   object
#  1   name         9992 non-null   object
#  2   desc         9986 non-null   object
#  3   price        9992 non-null   float64
#  4   promo_price  9992 non-null   object
#  5   in_stock     9992 non-null   int64
#  6   type         9946 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 624.5+ KB

# %% [markdown]
# #### `promo_price`

# %% [markdown]
# Again, let's begin by seeing how many values are affected by the 2-decimal-dots problem, or the 3 decimal-places problem

# %%
promo_problems_number = products_df.loc[(products_df.promo_price.astype(str).str.contains("\d+\.\d+\.\d+"))|(products_df.promo_price.astype(str).str.contains("\d+\.\d{3,}")), :].shape[0]
promo_problems_number
# Out:
# 9232

# %%
print(f"The column promo_price has in total {promo_problems_number} wrong values. This is {round(((promo_problems_number / products_df.shape[0]) * 100), 2)}% of the rows of the DataFrame")
# Out:
# The column promo_price has in total 9232 wrong values. This is 92.39% of the rows of the DataFrame

# %%
promo_price_df = products_df.loc[(products_df.promo_price.astype(str).str.contains("\d+\.\d+\.\d+"))|(products_df.promo_price.astype(str).str.contains("\d+\.\d{3,}")), :]
promo_price_df.sample(50)
# Out:
#              sku                                               name  \
# 11334    TRN0011       MacBook sleeve Sleeve Trunk / Air 13 "Silver
# 13426    APP1809                     Apple Apple Pack 4 Pencil Tips
# 13172    PAC1507  Pack QNAP TS-251A NAS Server | 2GB RAM | WD 8T...
# 1881   CRU0037-4  Crucial Mac Memory 32GB (4x8GB) 1866MHz DDR3 DIMM
# 15207    ELA0022       elago Lightning Cable 1m Aluminum Space Gray
# 9114     APP1257  Apple iMac 21.5 "Core i5 2.8GHz | 8GB | 1TB Fu...
# 12963  BNQ0039-A          (Open) LED Monitor Benq GW2470H 238 "HDMI
# 19188    XRI0011                   X-Rite color calibrator i1Studio
# 16846    GLY0011  Glyph Atom SSD SSD RAID 2TB USB-C (3.1Gen2) Si...
# 15921    PAC2311  Synology DS1517 + NAS Server | 2GB RAM | 60TB ...
# 12574    IFX0070  iFixit part adhesive strips Battery iPhone 6 Plus
# 2564     TUC0203  Tucano MacBook Pro Backpack Livello Up / Retin...
# 18008    MOS0241    Moshi iPhone Case StealthCover X Rosa Champagne
# 17595    OWC0236  OWC USB Travel Dock-C / USB 3.1 / HDMI / SD Ca...
# 12964  TRA0017-A  Open - Transcend JetDrive SSD 720 240GB Macboo...
# 15020    BEL0300  Belkin Rockstar Lightning Audio Adapter + Char...
# 16663    APP2142  Apple iPad Pro 10.5 "Wi-Fi + Cellular 512GB Si...
# 516      SEV0007             RAM installation service MacBook / Pro
# 354      APP0431                          Apple iPod nano 16Gb Blue
# 15475    REP0386                 Repair iPad Mini 3 Headphone Input
# 11899    QDO0012  QDOS OptiGuard Titanium protector iPhone 6s Pl...
# 17860    PAC2228  Synology DS218 + NAS Server | 2GB RAM | 8TB (2...
# 2548     BOS0019                   Bose SoundLink Color Red Speaker
# 15082  APP0271-A  Open - Apple Wireless Keyboard Keyboard (OEM) Mac
# 17766    PAC2398  DS418play Synology NAS Server | 6GB RAM | 32TB...
# 2609     DEN0011                         Denon Heos 5 Black Speaker
# 17267    AP20278  Like new - Apple Watch 42mm steel case and str...
# 687      PAC0494  Apple Mac Pro Quad-Core 37GHz | 64GB RAM | 512...
# 13619    APP1801  Apple Correa 42mm Braiding Nailon Pale Pink / ...
# 12944    SPH0015                  Sphero Robot Ollie Darkside Black
# 13418    APP1697       Apple iPhone Leather Case Cover Black Plus 7
# 13586    APP1726  Apple Watch Series 2 42mm Stainless Steel Case...
# 15709    STC0009   Stacked Wall Charger Wireless Charger White wall
# 11892  LOG0144-A  (Open) Logitech + iPhone support clamp Univers...
# 13079    GTE0066  G-Technology G-DRIVE mobile USB 3.0 500GB FW80...
# 19032    OWC0278         ThunderBay OWC Dual Thunderbolt RAID 5 4 3
# 13024    PAC1489  Samsung SSD 850 expansion kit EVO 500 GB to 21...
# 17317    WDT0392  WD My Passport 1TB USB External Hard Drive 25 ...
# 1707     BEL0172    Belkin Slim-Fit Armband Plus iPhone 6 / 6S Rosa
# 10737    ICA0056   Incase Systm Smart Case Cover iPhone 6 / 6S Gray
# 11654    UAG0034          UAG Ash MacBook Pro Retina Case 13 "Black
# 5613     PAC1055  Apple iMac 27 "Core i7 Retina 5K 4GHz | 32GB |...
# 9153     APP1260  Apple iMac 21.5 "Core i5 2.8GHz | 16GB | 2TB F...
# 2847     HOM0007          Homido Virtual Reality Headset for iPhone
# 13594    APP1732  Apple Watch Series 2 42mm Case Stainless Steel...
# 11625    OWC0177  OWC USB-C Dock USB 3.1 / HDMI / Audio / Giga E...
# 12995  WDT0302-A  (Open) Western Digital Elements Desktop USB 3....
# 13353    OTT0164  OtterBox Defender iPhone Case Black Triple Lay...
# 17429    AP20326          Like new - Apple iPhone 7 Plus 256GB Gold
# 317      NTE0017        NewerTech NuPower Battery MacBook 13 "white
#
#                                                     desc    price promo_price  \
# 11334  Neoprene with reinforced zipper MacBook Air 13...    39.95     179.903
# 13426                    4 extra points for Apple Pencil    25.00     249.998
# 13172  NAS with 2GB of RAM and two hard drives 4TB (2...   687.69   5.511.792
# 1881                      RAM 32GB (4x8GB) Mac Pro 2013.   463.96   4.629.896
# 15207  Charging cable connection and synchronization ...    17.99     159.889
# 9114   PC 215 inch iMac 2.8GHz 8GB RAM 1TB Fusion (MK...  1798.00   1.684.585
# 12963  LED monitor flicker-inch 238 free technology a...   139.99   1.300.812
# 19188  Calibrator and profiler monitors and color pri...   519.09   4.649.897
# 16846  2TB SSD with USB-C connection (compatible Thun...  1033.99   8.399.941
# 15921  NAS server with 2GB of RAM and 60TB for Mac an...  3305.81   2.647.912
# 12574  adhesive strips replacement battery for iPhone...     5.99      39.906
# 2564   Backpack with anti-shock MacBook Pro / Retina ...    59.99     299.899
# 18008  360-degree protection of military grade that r...    40.00     329.894
# 17595  Dock USB-C multiple connections and SD reader ...    66.99     539.902
# 12964  SSD Hard Drive 240GB + Tools Macbook Pro Retin...   245.00   2.175.846
# 15020  Lightning adapter plug and two input ports Lig...    39.99     349.896
# 16663                Pro New iPad Wi-Fi + Cellular 512GB  1279.00  12.390.013
# 516           Installation of RAM in your MacBook / Pro.    19.99     199.892
# 354       Music player iPod nano 7 Generation 16GB blue.   179.00   1.699.929
# 15475  Repair service including parts and labor for i...    79.99     799.895
# 11899  Crystal screen protector with metal finishing ...    24.99     119.899
# 17860  NAS storage server integrated with special foc...   682.99   5.881.786
# 2548   Bluetooth wireless speaker for iPhone iPad and...   139.00   1.349.876
# 15082  Ultrathin keyboard Apple Bluetooth Spanish (un...    79.00     490.601
# 17766  4-bay NAS server to accommodate 4K Ultra HD files  1996.94  14.313.683
# 2609   Medium-sized speaker with amazing sound for iP...   399.00   3.989.975
# 17267                  Apple Watch 42 mm refitted as new   869.00   3.989.999
# 687    New Apple Mac Pro Quad-Core 37GHz 64GB Flash R...  5729.00  46.809.903
# 13619  Braided nylon strap with four layers of tissue...    59.00     589.996
# 12944     Bluetooth Robot led by APP for iPhone and iPad   139.95   1.199.897
# 13418  ultrathin leather case and microfiber premium ...    59.00     490.002
# 13586  Apple Watch 42 mm dual core processor with GPS...   719.00   7.190.002
# 15709        magnetic wall charger for batteries Stacked    24.99     249.901
# 11892               Clamp holder with magnet for iPhone.    29.90     236.265
# 13079  500GB external hard drive with aluminum housin...   146.95     839.897
# 19032  outer box with RAID5 disc 25 inch and 35 inch ...   725.99   6.899.904
# 13024  SSD upgrade kit 500GB for 215-inch iMac Late 2...   222.97   1.665.843
# 17317  1TB External Hard Drive USB 3.0 with Mac and P...    89.99     689.942
# 1707             Bracelet perfect fit for iPhone 6 / 6S.    24.99     199.904
# 10737                 Double casing layer iPhone 6 / 6s.    34.95     219.905
# 11654  rigid and lightweight MacBook Pro Retina 13 in...    69.95     649.903
# 5613   IMac desktop computer 27 inch 5K Retina 4GHz i...  3949.00  33.669.896
# 9153   PC 215 inch iMac 2.8GHz RAM 16GB 2TB Fusion (M...  2278.00  21.325.851
# 2847       Virtual reality helmet adjustable for iPhone.    69.99     599.906
# 13594  Apple Watch 42 mm dual core processor with GPS...  1269.00  12.689.996
# 11625  Dock USB-C multiple connections and SD reader ...   217.99   1.499.892
# 12995  Elegant and lightweight external hard 4TB disk...   149.99   1.277.945
# 13353  Sleeve ultra-resistant anti certified Falls iP...    59.99     419.894
# 17429  Apple iPhone 7 Plus Free Refurbished 256GB Col...  1130.33   8.890.015
# 317              133 inch MacBook battery (White Model).   119.99     899.901
#
#        in_stock       type
# 11334         0   13835403
# 13426         0       1229
# 13172         0   12175397
# 1881          0       1364
# 15207         1       1230
# 9114          0       1282
# 12963         0       1298
# 19188         0   12355400
# 16846         0   11935397
# 15921         0   12175397
# 12574         0       5407
# 2564          0       1392
# 18008         1   11865403
# 17595         1   12995397
# 12964         0   12655397
# 15020         1   14365395
# 16663         0  106431714
# 516           0   20642062
# 354           0   11821715
# 15475         0   1,44E+11
# 11899         0   13555403
# 17860         1   12175397
# 2548          0       5398
# 15082         0       1298
# 17766         0   12175397
# 2609          0       5398
# 17267         0   24895185
# 687           0       1282
# 13619         0       2449
# 12944         0   11905404
# 13418         0   11865403
# 13586         0   24895185
# 15709         0       5399
# 11892         0       1298
# 13079         0   11935397
# 19032         1   11935397
# 13024         0       1433
# 17317         1   11935397
# 1707          0       5405
# 10737         0   11865403
# 11654         0   13835403
# 5613          0   5,74E+15
# 9153          0       1282
# 2847          0   11905404
# 13594         0   24895185
# 11625         0   12585395
# 12995         0       1298
# 13353         0   11865403
# 17429         0   85651716
# 317           1      10142

# %% [markdown]
# Over 90% of the data in this column is corrupt. There's no point deleting all of these rows, then I would barely have a products table. Instead, as it's only this column that appears to be very untrustworthy, I will delete the column.

# %%
products_cl = products_df.drop(columns=["promo_price"])

# %%
products_cl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9992 entries, 0 to 19325
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sku       9992 non-null   object
#  1   name      9992 non-null   object
#  2   desc      9986 non-null   object
#  3   price     9992 non-null   float64
#  4   in_stock  9992 non-null   int64
#  5   type      9946 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 546.4+ KB

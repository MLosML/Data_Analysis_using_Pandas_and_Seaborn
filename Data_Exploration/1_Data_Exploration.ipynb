# %%
import pandas as pd

# %%
url = "https://drive.google.com/file/d/1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG/view?usp=sharing" # orderlines.csv
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df = pd.read_csv(path)

# %% [markdown]
# #DataFrame dimensions

# %%
df.shape
# Out:
# (293983, 7)

# %%
nrows = df.shape[0]
ncols = df.shape[1]
print("The number of rows is", nrows)
print("The number of columns is", ncols)
# Out:
# The number of rows is 293983
# The number of columns is 7

# %%
df.size
# Out:
# 2057881

# %% [markdown]
# We can check if the `.size` and `.shape` agree

# %%
df.shape[0] * df.shape[1] == df.size
# Out:
# True

# %% [markdown]
# ##DataFrames exploration

# %%
df.head()
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57
# 3  2017-01-01 00:51:40
# 4  2017-01-01 01:06:38

# %%
df.tail()
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 293978  1650199    527398           0                 1  JBL0122      42.99
# 293979  1650200    527399           0                 1  PAC0653     141.58
# 293980  1650201    527400           0                 2  APP0698       9.99
# 293981  1650202    527388           0                 1  BEZ0204      19.99
# 293982  1650203    527401           0                 1  APP0927      13.99
#
#                        date
# 293978  2018-03-14 13:57:25
# 293979  2018-03-14 13:57:34
# 293980  2018-03-14 13:57:41
# 293981  2018-03-14 13:58:01
# 293982  2018-03-14 13:58:36

# %%
df.sample(10)
# Out:
#              id  id_order  product_id  product_quantity        sku unit_price  \
# 168820  1448784    444211           0                 1    APP0663     183.99
# 242421  1568241    493743           0                 1    APP1216     130.00
# 102265  1314105    387562           0                 1    APP2204   2.190.59
# 66999   1250983    357282           0                 1    WDT0316      52.99
# 166646  1445454    442823           0                 1    SAN0133      42.13
# 212392  1515704    471829           0                 1    APP0663     195.02
# 84276   1281218    372040           0                 1    MUV0183       8.99
# 87609   1287200    374882           0                 1    BEL0208      27.99
# 78275   1270751    366997           0                 1    PAC2053     199.00
# 55786   1231456    347808           0                 4    OWC0091      21.06
# 290585  1644782    524931           0                 1    WDT0341     472.19
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %%
df.describe()
# Out:
#                  id       id_order  product_id  product_quantity
# count  2.939830e+05  293983.000000    293983.0     293983.000000
# mean   1.397918e+06  419999.116544         0.0          1.121126
# std    1.530096e+05   66344.486479         0.0          3.396569
# min    1.119109e+06  241319.000000         0.0          1.000000
# 25%    1.262542e+06  362258.500000         0.0          1.000000
# 50%    1.406940e+06  425956.000000         0.0          1.000000
# 75%    1.531322e+06  478657.000000         0.0          1.000000
# max    1.650203e+06  527401.000000         0.0        999.000000

# %%
df.nunique()
# Out:
# id                  293983
# id_order            204855
# product_id               1
# product_quantity        67
# sku                   7951
# unit_price           11329
# date                251631
# dtype: int64

# %%
df["sku"].unique()[:10]
# Out:
# array(['OTT0133', 'LGE0043', 'PAR0071', 'WDT0315', 'JBL0104', 'WDT0249',
#        'APP1582', 'OWC0100', 'IOT0014', 'APP0700'], dtype=object)

# %%
df.isna()
# Out:
#            id  id_order  product_id  product_quantity    sku  unit_price  \
# 0       False     False       False             False  False       False
# 1       False     False       False             False  False       False
# 2       False     False       False             False  False       False
# 3       False     False       False             False  False       False
# 4       False     False       False             False  False       False
# ...       ...       ...         ...               ...    ...         ...
# 293978  False     False       False             False  False       False
# 293979  False     False       False             False  False       False
# 293980  False     False       False             False  False       False
# 293981  False     False       False             False  False       False
# 293982  False     False       False             False  False       False
#
#          date
# 0       False
# 1       False
# 2       False
# 3       False
# ...

# %%
df.isna().sum()
# Out:
# id                  0
# id_order            0
# product_id          0
# product_quantity    0
# sku                 0
# unit_price          0
# date                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
999*56
# Out:
# 55944

# %%
df.nlargest(5, "product_quantity")
# Out:
#             id  id_order  product_id  product_quantity      sku unit_price  \
# 53860  1228150    346221           0               999  APP1190      55.99
# 68712  1254032    358747           0               999  SEV0028      19.99
# 57796  1234924    349475           0               800  KIN0137       7.49
# 57306  1234111    349133           0               555  APP0665      70.99
# 40813  1204788    335057           0               201  THU0029      80.99
#
#                       date
# 53860  2017-04-14 21:50:52
# 68712  2017-05-24 14:51:58
# 57796  2017-04-25 09:59:00
# 57306  2017-04-24 10:20:13
# 40813  2017-03-14 15:25:53

# %%
df.nsmallest(5, "product_quantity")
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57
# 3  2017-01-01 00:51:40
# 4  2017-01-01 01:06:38

# %% [markdown]
# ##Select Columns

# %%
df["id_order"]
# Out:
# 0         299539
# 1         299540
# 2         299541
# 3         299542
# 4         299543
#            ...
# 293978    527398
# 293979    527399
# 293980    527400
# 293981    527388
# 293982    527401
# Name: id_order, Length: 293983, dtype: int64

# %%
df.loc[:, "id_order"]
# Out:
# 0         299539
# 1         299540
# 2         299541
# 3         299542
# 4         299543
#            ...
# 293978    527398
# 293979    527399
# 293980    527400
# 293981    527388
# 293982    527401
# Name: id_order, Length: 293983, dtype: int64

# %%
df.iloc[:, 1]
# Out:
# 0         299539
# 1         299540
# 2         299541
# 3         299542
# 4         299543
#            ...
# 293978    527398
# 293979    527399
# 293980    527400
# 293981    527388
# 293982    527401
# Name: id_order, Length: 293983, dtype: int64

# %% [markdown]
# ###Select multiple columns

# %%
df[["id_order","sku"]]
# Out:
#         id_order      sku
# 0         299539  OTT0133
# 1         299540  LGE0043
# 2         299541  PAR0071
# 3         299542  WDT0315
# 4         299543  JBL0104
# ...          ...      ...
# 293978    527398  JBL0122
# 293979    527399  PAC0653
# 293980    527400  APP0698
# 293981    527388  BEZ0204
# 293982    527401  APP0927
#
# [293983 rows x 2 columns]

# %%
df.loc[:, ["id_order", "sku"]]
# Out:
#         id_order      sku
# 0         299539  OTT0133
# 1         299540  LGE0043
# 2         299541  PAR0071
# 3         299542  WDT0315
# 4         299543  JBL0104
# ...          ...      ...
# 293978    527398  JBL0122
# 293979    527399  PAC0653
# 293980    527400  APP0698
# 293981    527388  BEZ0204
# 293982    527401  APP0927
#
# [293983 rows x 2 columns]

# %%
df.loc[:, "id_order":"sku"]
# Out:
#         id_order  product_id  product_quantity      sku
# 0         299539           0                 1  OTT0133
# 1         299540           0                 1  LGE0043
# 2         299541           0                 1  PAR0071
# 3         299542           0                 1  WDT0315
# 4         299543           0                 1  JBL0104
# ...          ...         ...               ...      ...
# 293978    527398           0                 1  JBL0122
# 293979    527399           0                 1  PAC0653
# 293980    527400           0                 2  APP0698
# 293981    527388           0                 1  BEZ0204
# 293982    527401           0                 1  APP0927
#
# [293983 rows x 4 columns]

# %%
df.iloc[:, [1, 4]]
# Out:
#         id_order      sku
# 0         299539  OTT0133
# 1         299540  LGE0043
# 2         299541  PAR0071
# 3         299542  WDT0315
# 4         299543  JBL0104
# ...          ...      ...
# 293978    527398  JBL0122
# 293979    527399  PAC0653
# 293980    527400  APP0698
# 293981    527388  BEZ0204
# 293982    527401  APP0927
#
# [293983 rows x 2 columns]

# %%
df.iloc[:, 1:5]
# Out:
#         id_order  product_id  product_quantity      sku
# 0         299539           0                 1  OTT0133
# 1         299540           0                 1  LGE0043
# 2         299541           0                 1  PAR0071
# 3         299542           0                 1  WDT0315
# 4         299543           0                 1  JBL0104
# ...          ...         ...               ...      ...
# 293978    527398           0                 1  JBL0122
# 293979    527399           0                 1  PAC0653
# 293980    527400           0                 2  APP0698
# 293981    527388           0                 1  BEZ0204
# 293982    527401           0                 1  APP0927
#
# [293983 rows x 4 columns]

# %% [markdown]
# ##Select Rows

# %%
df.loc[54, :]
# Out:
# id                              1119209
# id_order                         299591
# product_id                            0
# product_quantity                      1
# sku                             BOO0066
# unit_price                         4.74
# date                2017-01-01 09:35:05
# Name: 54, dtype: object

# %%
df.loc[0:3, :]
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57
# 3  2017-01-01 00:51:40

# %%
df = df.set_index("id")
df
# Out:
#          id_order  product_id  product_quantity      sku unit_price  \
# id
# 1119109    299539           0                 1  OTT0133      18.99
# 1119110    299540           0                 1  LGE0043     399.00
# 1119111    299541           0                 1  PAR0071     474.05
# 1119112    299542           0                 1  WDT0315      68.39
# 1119113    299543           0                 1  JBL0104      23.74
# ...           ...         ...               ...      ...        ...
# 1650199    527398           0                 1  JBL0122      42.99
# 1650200    527399           0                 1  PAC0653     141.58
# 1650201    527400           0                 2  APP0698       9.99
# 1650202    527388           0                 1  BEZ0204      19.99
# 1650203    527401           0                 1  APP0927      13.99
#
#                         date
# id
# 1119109  2017-01-01 00:07:19
# 1119110  2017-01-01 00:19:45
# 1119111  2017-01-01 00:20:57
# ...

# %%
df.set_index("id", inplace=True)

# %%
df.loc[0:3, :]
# Out:
# Empty DataFrame
# Columns: [id_order, product_id, product_quantity, sku, unit_price, date]
# Index: []

# %%
df.loc[1119109:1119112, :]
# Out:
#          id_order  product_id  product_quantity      sku unit_price  \
# id
# 1119109    299539           0                 1  OTT0133      18.99
# 1119110    299540           0                 1  LGE0043     399.00
# 1119111    299541           0                 1  PAR0071     474.05
# 1119112    299542           0                 1  WDT0315      68.39
#
#                         date
# id
# 1119109  2017-01-01 00:07:19
# 1119110  2017-01-01 00:19:45
# 1119111  2017-01-01 00:20:57
# 1119112  2017-01-01 00:51:40

# %%
df.iloc[0:4]
# Out:
#          id_order  product_id  product_quantity      sku unit_price  \
# id
# 1119109    299539           0                 1  OTT0133      18.99
# 1119110    299540           0                 1  LGE0043     399.00
# 1119111    299541           0                 1  PAR0071     474.05
# 1119112    299542           0                 1  WDT0315      68.39
#
#                         date
# id
# 1119109  2017-01-01 00:07:19
# 1119110  2017-01-01 00:19:45
# 1119111  2017-01-01 00:20:57
# 1119112  2017-01-01 00:51:40

# %%
df.iloc[-1]
# Out:
# id_order                         527401
# product_id                            0
# product_quantity                      1
# sku                             APP0927
# unit_price                        13.99
# date                2018-03-14 13:58:36
# Name: 1650203, dtype: object

# %%
df = df.reset_index()
df
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 0       1119109    299539           0                 1  OTT0133      18.99
# 1       1119110    299540           0                 1  LGE0043     399.00
# 2       1119111    299541           0                 1  PAR0071     474.05
# 3       1119112    299542           0                 1  WDT0315      68.39
# 4       1119113    299543           0                 1  JBL0104      23.74
# ...         ...       ...         ...               ...      ...        ...
# 293978  1650199    527398           0                 1  JBL0122      42.99
# 293979  1650200    527399           0                 1  PAC0653     141.58
# 293980  1650201    527400           0                 2  APP0698       9.99
# 293981  1650202    527388           0                 1  BEZ0204      19.99
# 293982  1650203    527401           0                 1  APP0927      13.99
#
#                        date
# ...

# %%
df.reset_index(inplace=True)

# %% [markdown]
# ##Drop Columns

# %%
df.drop(["unit_price"], axis=1)
# Out:
#              id  id_order  product_id  product_quantity      sku  \
# 0       1119109    299539           0                 1  OTT0133
# 1       1119110    299540           0                 1  LGE0043
# 2       1119111    299541           0                 1  PAR0071
# 3       1119112    299542           0                 1  WDT0315
# 4       1119113    299543           0                 1  JBL0104
# ...         ...       ...         ...               ...      ...
# 293978  1650199    527398           0                 1  JBL0122
# 293979  1650200    527399           0                 1  PAC0653
# 293980  1650201    527400           0                 2  APP0698
# 293981  1650202    527388           0                 1  BEZ0204
# 293982  1650203    527401           0                 1  APP0927
#
#                        date
# 0       2017-01-01 00:07:19
# 1       2017-01-01 00:19:45
# 2       2017-01-01 00:20:57
# 3       2017-01-01 00:51:40
# 4       2017-01-01 01:06:38
# ...

# %% [markdown]
# ##Filter rows based on conditions

# %%
df.loc[df["product_quantity"] > 100, :]
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 27779   1180010    323959           0               126  ADN0039      34.99
# 40813   1204788    335057           0               201  THU0029      80.99
# 53860   1228150    346221           0               999  APP1190      55.99
# 57306   1234111    349133           0               555  APP0665      70.99
# 57796   1234924    349475           0               800  KIN0137       7.49
# 68712   1254032    358747           0               999  SEV0028      19.99
# 136675  1388261    417536           0               200  TRK0009      29.99
# 204637  1500715    464858           0               192  APP1662     519.00
# 246048  1574262    496172           0               164  EVU0013      19.99
# 285492  1637611    522075           0               125  XDO0047      25.99
#
#                        date
# 27779   2017-02-14 10:21:12
# 40813   2017-03-14 15:25:53
# 53860   2017-04-14 21:50:52
# ...

# %%
df.query("product_quantity > 100")
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 27779   1180010    323959           0               126  ADN0039      34.99
# 40813   1204788    335057           0               201  THU0029      80.99
# 53860   1228150    346221           0               999  APP1190      55.99
# 57306   1234111    349133           0               555  APP0665      70.99
# 57796   1234924    349475           0               800  KIN0137       7.49
# 68712   1254032    358747           0               999  SEV0028      19.99
# 136675  1388261    417536           0               200  TRK0009      29.99
# 204637  1500715    464858           0               192  APP1662     519.00
# 246048  1574262    496172           0               164  EVU0013      19.99
# 285492  1637611    522075           0               125  XDO0047      25.99
#
#                        date
# 27779   2017-02-14 10:21:12
# 40813   2017-03-14 15:25:53
# 53860   2017-04-14 21:50:52
# ...

# %%
# find out a column that contains a list
df["sku"].isin(["JBL0104", "ADN0039"])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4          True
#           ...
# 293978    False
# 293979    False
# 293980    False
# 293981    False
# 293982    False
# Name: sku, Length: 293983, dtype: bool

# %%
df.loc[df["sku"].isin(["JBL0104", "ADN0039"]), :]
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 4       1119113    299543           0                 1  JBL0104      23.74
# 716     1120463    300212           0                 2  JBL0104      26.99
# 774     1120607    300272           0                 1  JBL0104      24.99
# 866     1120758    300349           0                 1  JBL0104      24.99
# 1411    1122014    300851           0                 1  JBL0104      24.99
# 1451    1122093    300887           0                 1  JBL0104      24.99
# 3612    1130604    302848           0                 1  JBL0104      24.99
# 4370    1132185    303586           0                 1  JBL0104      22.31
# 7028    1137895    305980           0                 1  ADN0039      34.99
# 8450    1140943    307256           0                 1  JBL0104      26.99
# 14439   1153300    312363           0                 1  JBL0104      26.99
# ...

# %%
pd.options.display.max_rows = 100

# %% [markdown]
# #### 7.1.&nbsp; Modifying a DataFrame & the `.copy()` method

# %%
sample = df.iloc[:3,:]
sample
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57

# %%
sample.iloc[0,4] = "NEW VALUE HERE"

# %%
sample
# Out:
#         id  id_order  product_id  product_quantity             sku unit_price  \
# 0  1119109    299539           0                 1  NEW VALUE HERE      18.99
# 1  1119110    299540           0                 1         LGE0043     399.00
# 2  1119111    299541           0                 1         PAR0071     474.05
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57

# %%
df.head(3)
# Out:
#         id  id_order  product_id  product_quantity             sku unit_price  \
# 0  1119109    299539           0                 1  NEW VALUE HERE      18.99
# 1  1119110    299540           0                 1         LGE0043     399.00
# 2  1119111    299541           0                 1         PAR0071     474.05
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57

# %%
import pandas as pd
url = "https://drive.google.com/file/d/1FYhN_2AzTBFuWcfHaRuKcuCE6CWXsWtG/view?usp=sharing" # orderlines.csv
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
df = pd.read_csv(path)

# %%
sample = df.iloc[:3,:].copy()
sample.iloc[0,4] = "NEW VALUE HERE"
sample
# Out:
#         id  id_order  product_id  product_quantity             sku unit_price  \
# 0  1119109    299539           0                 1  NEW VALUE HERE      18.99
# 1  1119110    299540           0                 1         LGE0043     399.00
# 2  1119111    299541           0                 1         PAR0071     474.05
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57

# %%
df.head(3)
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
#
#                   date
# 0  2017-01-01 00:07:19
# 1  2017-01-01 00:19:45
# 2  2017-01-01 00:20:57

# %% [markdown]
# # CHALLENGES

# %% [markdown]
# 1. How many different unit prices does the product with the sku JBL0104 have? Combine a pandas filter method with the method `.nunique()`.

# %%
filt_data = df[df['sku'] == 'JBL0104']

unit_prices_uni_count = filt_data['unit_price'].nunique()

print(f"The product with SKU JBL0104 has {unit_prices_uni_count} different unit prices.")
# Out:
# The product with SKU JBL0104 has 7 different unit prices.

# %%
df.loc[df["sku"] == "JBL0104", "unit_price"].nunique()
# Out:
# 7

# %%
df.loc[df["sku"].isin(["JBL0104"]), 'unit_price'].nunique()
# Out:
# 7

# %%
(df
 .query("sku == 'JBL0104'")
 ["unit_price"]
 .nunique())
# Out:
# 7

# %% [markdown]
# 2.List the (unique) items that were sold in the order with the id_order 385921.

# %%
df.loc[df["id_order"] == 385921, "sku"].unique().tolist()
# Out:
# ['APP2431',
#  'APP2348',
#  'APP2131',
#  'APP1630',
#  'APP1735',
#  'APP1216',
#  'APP2092',
#  'APP1215',
#  'ELA0017',
#  'MIN0010',
#  'ELA0039',
#  'BEA0046',
#  'BOS0034',
#  'BEA0071',
#  'ELA0029',
#  'APP2161',
#  'HOC0008',
#  'NOM0026',
#  'NOM0014']

# %%
list(df.loc[df["id_order"] == 385921, "sku"].unique())
# Out:
# ['APP2431',
#  'APP2348',
#  'APP2131',
#  'APP1630',
#  'APP1735',
#  'APP1216',
#  'APP2092',
#  'APP1215',
#  'ELA0017',
#  'MIN0010',
#  'ELA0039',
#  'BEA0046',
#  'BOS0034',
#  'BEA0071',
#  'ELA0029',
#  'APP2161',
#  'HOC0008',
#  'NOM0026',
#  'NOM0014']

# %%
list(df.loc[df["id_order"].isin([385921]), "sku"].unique())
# Out:
# ['APP2431',
#  'APP2348',
#  'APP2131',
#  'APP1630',
#  'APP1735',
#  'APP1216',
#  'APP2092',
#  'APP1215',
#  'ELA0017',
#  'MIN0010',
#  'ELA0039',
#  'BEA0046',
#  'BOS0034',
#  'BEA0071',
#  'ELA0029',
#  'APP2161',
#  'HOC0008',
#  'NOM0026',
#  'NOM0014']

# %%
df.query("id_order == 385921")["sku"].unique().tolist()
# Out:
# ['APP2431',
#  'APP2348',
#  'APP2131',
#  'APP1630',
#  'APP1735',
#  'APP1216',
#  'APP2092',
#  'APP1215',
#  'ELA0017',
#  'MIN0010',
#  'ELA0039',
#  'BEA0046',
#  'BOS0034',
#  'BEA0071',
#  'ELA0029',
#  'APP2161',
#  'HOC0008',
#  'NOM0026',
#  'NOM0014']

# %% [markdown]
# 3.Consider the products with the skus APP2431 and APP2348. Find out in how many orders they were present.

# %%
df.loc[df["sku"].isin(["APP2431", "APP2348"]),:].groupby("sku")["id_order"].nunique()
# Out:
# sku
# APP2348    119
# APP2431     70
# Name: id_order, dtype: int64

# %%
df.loc[(df["sku"] == "APP2431")|(df["sku"] == "APP2348"), "id_order"].nunique()
# Out:
# 179

# %%
df.loc[df["sku"].isin(["APP2431","APP2348"]), "id_order"].nunique()
# Out:
# 179

# %%
df.query("sku == ['APP2431','APP2348']")["id_order"].nunique()
# Out:
# 179

# %% [markdown]
# 4.Create a new DataFrame, `df_50`, with all the rows that have a product quantity higher than 500 and only the columns `id`, `product_id`, `product_quantity` and `sku`. Be sure to use the method `.copy()`. Once the new DataFrame is created, modify the column "product_quantity" to "quantity", and "sku" to "product_code". To do so, you can use the method `.rename()` or assign a list of new names to the attribute `.columns`.

# %% [markdown]
# Creating `df_50`

# %%
over_500_mask = df['product_quantity'] > 500
df_50 = df.loc[over_500_mask, ['id', 'product_id', 'product_quantity', 'sku']].copy()

new_column_names = {'product_quantity':'quantity', 'sku': 'product_code'}
df_50 = df_50.rename(columns=new_column_names)
df_50
# Out:
#             id  product_id  quantity product_code
# 53860  1228150           0       999      APP1190
# 57306  1234111           0       555      APP0665
# 57796  1234924           0       800      KIN0137
# 68712  1254032           0       999      SEV0028

# %%
df_50 = df.query("product_quantity > 500").loc[:,("id", "product_id", "product_quantity" , "sku")].copy()
df_50
# Out:
#             id  product_id  product_quantity      sku
# 53860  1228150           0               999  APP1190
# 57306  1234111           0               555  APP0665
# 57796  1234924           0               800  KIN0137
# 68712  1254032           0               999  SEV0028

# %% [markdown]
# Renaming columns of `df_50`

# %%
df_50.columns = ["id","product_id","quantity","product_code"]
df_50
# Out:
#             id  product_id  quantity product_code
# 53860  1228150           0       999      APP1190
# 57306  1234111           0       555      APP0665
# 57796  1234924           0       800      KIN0137
# 68712  1254032           0       999      SEV0028

# %%
url = "https://drive.google.com/file/d/1Vu0q91qZw6lqhIqbjoXYvYAQTmVHh6uZ/view?usp=sharing" # orders.csv
path = "https://drive.google.com/uc?export=download&id="+url.split("/")[-2]
orders_df = pd.read_csv(path)

# %%
orders_df
# Out:
#         order_id         created_date  total_paid            state
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled
# 1         241423  2017-11-06 13:10:02      136.15        Completed
# 2         242832  2017-12-31 17:40:03       15.76        Completed
# 3         243330  2017-02-16 10:59:38       84.98        Completed
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                  ...         ...              ...
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order
#
# [226909 rows x 4 columns]

# %%
orders_df.value_counts("state")#.reset_index().loc[1, "count"]
# Out:
# state
# Shopping Basket    117809
# Completed           46605
# Place Order         40883
# Pending             14379
# Cancelled            7233
# Name: count, dtype: int64
